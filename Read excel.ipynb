# %%
import os
import pandas

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'Read csv.ipynb',
#  'Read json.ipynb',
#  'README.md',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
data_file = pandas.read_excel("supermarkets.xlsx")
data_file
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
data_file = pandas.read_excel("supermarkets.xlsx", header = None)
data_file
# Out:
#     0                1              2                 3        4  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#                   5                    6
# 0  Supermarket Name  Number of Employees
# 1           Madeira                    8
# 2       Bready Shop                   15
# 3       Super River                   25
# 4        Ben's Shop                   10
# 5           Sanchez                   12
# 6        Richvalley                   20

# %%
data_file = pandas.read_excel("supermarkets.xlsx")
data_file.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
data_file = pandas.read_excel("supermarkets.xlsx", sheetname = 1)
data_file
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data_file = pandas.read_excel("supermarkets.xlsx", sheetname = 0)
data_file
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20
